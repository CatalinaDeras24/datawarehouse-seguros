# %% [markdown]
# <a href="https://colab.research.google.com/github/CatalinaDeras24/datawarehouse-seguros/blob/main/Notebook/Aseguradoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/CatalinaDeras24/etl-data-pipeline/refs/heads/main/data/raw/aseguradoras.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador             B

# %% [markdown]
# Exploracion de datos

# %%
df.shape
# Out:
# (15, 4)

# %%
df.columns
# Out:
# Index(['id_aseguradora', 'nombre', 'pais', 'rating_riesgo'], dtype='object')

# %%
df.isnull().sum()
# Out:
# id_aseguradora    0
# nombre            0
# pais              2
# rating_riesgo     3
# dtype: int64

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
aseguradoras= df.copy()

# %%
aseguradoras['rating_riesgo']= aseguradoras['rating_riesgo'].replace('B', 'Bajo')

# %%
aseguradoras.head()
# Out:
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador          Bajo

# %%
aseguradoras['rating_riesgo']= aseguradoras['rating_riesgo'].replace('B', 'Bajo')
aseguradoras['rating_riesgo']= aseguradoras['rating_riesgo'].replace('M', 'Medio')
aseguradoras['rating_riesgo']= aseguradoras['rating_riesgo'].replace('A', 'Alto')
